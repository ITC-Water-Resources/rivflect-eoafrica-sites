# %% [markdown]
# ![Rivflect_banner.png](attachment:1b4aca30-d6a5-4519-91c2-13f052cff260.png)
#
# # Notebook to plan and design the GNSS-R dployment at Entebbe Site
#
# Zeleke Challa, Roelof Rietbroek, Sept 2023

# %%
#only need to be run once to install some gnss tools from the project ()
# !pip install git+https://github.com/ITC-Water-Resources/gnssr4water.git

# %%
import geopandas as gpd
from gnssr4water.fresnel.getorbits import retrieve_orbits,read_sp3
from gnssr4water.fresnel.iterfresnel import reflZone
from gnssr4water.fresnel.geod import elevazim
from gnssr4water.fresnel.plotfresnel import fresnelMap
from datetime import datetime

# %%
# load hydromet stations
hydrometshapef='data/HydroMet_Locations'
hydromdf=gpd.read_file(hydrometshapef)
display(hydromdf)
# Out:
#     OBJECTID  No_      Country                               Stations  \
# 0          1    1      BURUNDI                       Ruvubu at Gitega
# 1          2    2      BURUNDI                      Ruvubu at Muyinga
# 2          3    3        KENYA                          Nzoia Ruambwa
# 3          4    4        KENYA                           Yala Kadenge
# 4          5    5        KENYA                           Nyando Ogilo
# 5          6    6        KENYA                            Miriu Sondu
# 6          7    7        KENYA                           Gucha Migori
# 7          8    8        KENYA                                   Mara
# 8          9    9       RWANDA                      Gakindo Lac Rweru
# 9         10   10       RWANDA                                Gihinga
# 10        11   11       RWANDA                              Kagitumba
# 11        12   12       RWANDA                               Kanzenze
# 12        13   13       RWANDA                    Shell Cyohoha south
# 13        14   14       RWANDA                         Akagera Outlet
# 14        15   15     TANZANIA                Mara River at Nyasurura
# 15        16   16     TANZANIA              Grumeti river at M Bridge
# 16        17   17     TANZANIA                               Mbalgeti
# 17        18   18     TANZANIA                  Kagera at Kyaka Ferry
# 18        19   19     TANZANIA                 Ruvuvu at Mwendo Ferry
# 19        20   20     TANZANIA                 Simiyu River at Lumeji
# 20        21   21     TANZANIA                  Kogatende Ranger Post
# 21        22   22     TANZANIA                           Rusumo Falls
# 22        23   23       UGANDA            Lake Victoria at Jinja Pier
# 23        24   24       UGANDA        River Katonga at Kampala-Masaka
# 24        25   25       UGANDA     River Sio at Luhalali near Bunadet
# 25        26   26       UGANDA       River Bukora at Mulukula-Kyotera
# 26        27   27       UGANDA             Lake Kyoga at Bugondo Pier
# 27        28   28       UGANDA       River Victoria Nile at Mbulamuti
# 28        29   29       UGANDA      River Malaba on Jinja-Tororo Road
# 29        30   30       UGANDA       River Kyoga Nile at Masindi Port
# 30        31   31       UGANDA              River Kyoga Nile at Paraa
# 31        32   32       UGANDA                   Lake Edward at Katwe
# 32        33   33       UGANDA                 Lake Albert at Butiaba
# 33        34   34       UGANDA             River Semliki at Bweramule
# 34        35   35       UGANDA            River Albert Nile at Laropi
# 35        36   36       UGANDA          River Albert Nile at Panyango
# 36        37   37       UGANDA               River Kagera at Nsongezi
# 37        38   38       UGANDA          Entebbe Demonstration Station
# 38        39   39  SOUTH SUDAN               Bahr El Jebel at Mangala
# 24          UGA_004_Hyd   0.321928  34.057100   POINT (34.05710 0.32193)
# 25          UGA_005_Hyd  -0.842583  31.488585  POINT (31.48859 -0.84258)
# 26          UGA_006_Hyd   1.620000  33.273670   POINT (33.27367 1.62000)
# 27          UGA_007_Hyd   0.835347  33.028100   POINT (33.02810 0.83535)
# 28          UGA_008_Hyd   0.585434  34.052000   POINT (34.05200 0.58543)
# 29          UGA_009_Hyd   1.695000  32.093000   POINT (32.09300 1.69500)
# 30          UGA_010_Hyd   2.283000  31.564000   POINT (31.56400 2.28300)
# 31          UGA_011_Hyd  -0.148400  29.882500  POINT (29.88250 -0.14840)
# 32          UGA_012_Hyd   1.819700  31.327500   POINT (31.32750 1.81970)
# 33          UGA_013_Hyd   0.955800  30.186100   POINT (30.18610 0.95580)
# 34          UGA_014_Hyd   3.552120  31.813200   POINT (31.81320 3.55212)
# 35          UGA_015_Hyd   2.470000  31.500000   POINT (31.50000 2.47000)
# 36          UGA_016_Hyd  -0.989459  30.756175  POINT (30.75618 -0.98946)
# 37          NBI_001_Hyd   0.048203  32.472742   POINT (32.47274 0.04820)
# 38          SSD_005_Hyd   5.198000  31.765000   POINT (31.76500 5.19800)
# 39          SSD-009_Hyd   3.722910  31.971000   POINT (31.97100 3.72291)
# 40          SSD-014_Hyd   3.593000  32.039000   POINT (32.03900 3.59300)
# 41          SSD-004_Hyd   9.533000  31.647000   POINT (31.64700 9.53300)
# 42          SSD_003_Hyd   9.355000  31.599000   POINT (31.59900 9.35500)
# 43          SUD_001_Hyd  11.239739  34.926540  POINT (34.92654 11.23974)
# 44          SUD_002_Hyd  11.890596  34.376200  POINT (34.37620 11.89060)
# 45          SUD_003_Hyd  14.427455  33.506649  POINT (33.50665 14.42746)
# 46          SUD_004_Hyd  15.611626  32.532823  POINT (32.53282 15.61163)
# 47          SUD_005_Hyd  13.337722  34.102308  POINT (34.10231 13.33772)
# 48          SUD_006_Hyd  13.415088  34.621703  POINT (34.62170 13.41509)
# 49          SUD_007_Hyd  17.679755  34.003685  POINT (34.00369 17.67976)
# 50          SUD_009_Hyd  17.560862  33.910570  POINT (33.91057 17.56086)
# 51          SUD_010_Hyd  19.181106  30.493183  POINT (30.49318 19.18111)
# 52          SUD_011_Hyd  13.612042  36.298598  POINT (36.29860 13.61204)
# 53          SUD_012_Hyd  14.255584  36.544274  POINT (36.54427 14.25558)
# 54          SUD_013_Hyd  12.588912  32.800045  POINT (32.80005 12.58891)
# 55          SUD_014_Hyd  15.713938  32.531806  POINT (32.53181 15.71394)

# %%
# select a station to consider
Entebbestat=hydromdf[hydromdf.Station_ID == 'NBI_001_Hyd']
lon=Entebbestat.geometry.x.item()
lat=Entebbestat.geometry.y.item()

#move the station to the lake bank:

lat=0.047
lon=32.4735

receiverh=4 #meter above water surface
print(f"Lon:{lon}, lat:{lat}, receiverheight:{receiverh}")
# Out:
# Lon:32.4735, lat:0.047, receiverheight:4

# %%
# get some reference GPS orbits
orb = retrieve_orbits(datetime(2023,9,8))
df_sp3 = read_sp3(orb)

 # Calculate elevation and azimuth
df_sp3 = elevazim(df_sp3,lon,lat,receiverh)

# Remove all values below 0° elevation, i.e satellites that are not visible
df_sp3 = df_sp3[df_sp3['elevation'] > 0]

display(df_sp3)
# Out:
# File already exists
#        PRN  week                date       tow       clock   system  \
# 0       13  2278 2023-09-08 18:00:00  496800.0  570.125879      GPS
# 1       22  2278 2023-09-08 18:00:00  496800.0  125.703480      GPS
# 3        7  2278 2023-09-08 18:00:00  496800.0   72.814242      GPS
# 4        5  2278 2023-09-08 18:00:00  496800.0 -141.948790      GPS
# 5       20  2278 2023-09-08 18:00:00  496800.0  412.921637      GPS
# ...    ...   ...                 ...       ...         ...      ...
# 10162    8  2279 2023-09-10 17:00:00   61200.0  -72.486430  GLONASS
# 10164    7  2279 2023-09-10 17:00:00   61200.0   64.360141  GLONASS
# 10165    2  2279 2023-09-10 17:00:00   61200.0  -22.431527  GLONASS
# 10169   21  2279 2023-09-10 17:00:00   61200.0  -37.029398  GLONASS
# 10172   12  2279 2023-09-10 17:00:00   61200.0   31.137564  GLONASS
#
#        elevation  azimuth
# 0             31      345
# 1             38        3
# 3              8       70
# 4             35      272
# 5             41      231
# ...          ...      ...
# 10162         63      157
# 10164         13      155
# 10165          4      335
# 10169         15       87
# 10172         25      313
#
# [3919 rows x 8 columns]

# %%
# create fresnel zones
reflZone(receiverh, [5,10,15],lon,lat,df_sp3=df_sp3)
# Out:
# File Fresnel[5, 10, 15]_4.gpkg successfully created in FresnelZones
#       ID  azimuth  elevation        area  \
# 0      0       17          5  357.523929
# 1      1       19          5  357.523929
# 2      2       26          5  357.523929
# 3      3       30          5  357.523929
# 4      4       33          5  357.523929
# ..   ...      ...        ...         ...
# 217  217      337         15   37.313164
# 218  218      338         15   37.313164
# 219  219      339         15   37.313164
# 220  220      340         15   37.313164
# 221  221      343         15   37.313164
#
#                                               geometry
# 0    POLYGON ((32.47375 0.04781, 32.47375 0.04781, ...
# 1    POLYGON ((32.47378 0.04780, 32.47377 0.04780, ...
# 2    POLYGON ((32.47387 0.04776, 32.47387 0.04776, ...
# 3    POLYGON ((32.47392 0.04773, 32.47392 0.04773, ...
# 4    POLYGON ((32.47396 0.04771, 32.47396 0.04771, ...
# ..                                                 ...
# 217  POLYGON ((32.47342 0.04719, 32.47342 0.04719, ...
# 218  POLYGON ((32.47342 0.04719, 32.47342 0.04719, ...
# 219  POLYGON ((32.47343 0.04719, 32.47342 0.04719, ...
# 220  POLYGON ((32.47343 0.04719, 32.47343 0.04719, ...
# 221  POLYGON ((32.47344 0.04720, 32.47344 0.04720, ...
#
# [222 rows x 5 columns]

# %%
# %matplotlib inline
fileFres=f"FresnelZones/Fresnel[5, 10, 15]_{receiverh}.gpkg"
fresnelMap(lon,lat,dist=60,filezone=fileFres)
# Out:
# No file for waterbody given
